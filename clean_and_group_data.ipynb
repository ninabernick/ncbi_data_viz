# %%
import marisa_trie
import boto3
import taxoniq
import re
import pickle
import sys
import pandas as pd
import numpy as np

# %% [markdown]
# Read in CSV file of all data with rank information, then clean data and group it.

# %% [markdown]
# Overall cleaning steps:
# - sum up accession counts and total lengths for 'other sequences' (entries with no superkingdom info), drop those rows, then add one row with the cumulative counts for 'other sequences'
# - fill in missing kingdom values with superkingdom values for bacteria and archaea
# - fill missing values with "unknown_{rank}"
# - group data by each rank down to desired level

# %%
all_data = pd.read_csv('test.csv')

# %%
all_data
# Out:
#         superkingdom         kingdom           phylum            class  \
# 0          Eukaryota         Metazoa         Chordata       Ascidiacea
# 1          Eukaryota         Metazoa       Arthropoda          Insecta
# 2          Eukaryota         Metazoa       Arthropoda          Insecta
# 3          Eukaryota         Metazoa         Chordata         Mammalia
# 4          Eukaryota         Metazoa         Chordata              NaN
# ...              ...             ...              ...              ...
# 1814807      Viruses  Heunggongvirae      Uroviricota   Caudoviricetes
# 1814808          NaN             NaN              NaN              NaN
# 1814809      Viruses  Heunggongvirae      Uroviricota   Caudoviricetes
# 1814810      Viruses   Orthornavirae  Negarnaviricota  Insthoviricetes
# 1814811      Viruses   Orthornavirae  Negarnaviricota  Insthoviricetes
#
#                    order            family                genus  \
# 0        Stolidobranchia         Styelidae               Styela
# 1              Hemiptera       Delphacidae          Nilaparvata
# 2            Hymenoptera        Formicidae           Solenopsis
# 3               Primates           Cebidae              Saimiri
# 4             Testudines       Geoemydidae             Mauremys
# ...                  ...               ...                  ...
# 1814807     Caudovirales    Herelleviridae           Okubovirus
# 1814808              NaN               NaN                  NaN
# 1814809     Caudovirales      Siphoviridae          Lambdavirus
# 1814810  Articulavirales  Orthomyxoviridae  Alphainfluenzavirus
# 1814811  Articulavirales  Orthomyxoviridae  Alphainfluenzavirus
#
#                       species  taxon_id  total_length  num_accessions
# 0                Styela clava      7725      82293180           30498
# 1          Nilaparvata lugens    108931     111856641           39851
# 2          Solenopsis invicta     13686     127796499           34709
# 3         Saimiri boliviensis     39432     154142035           53060
# 4           Mauremys reevesii    260615     263305466           86524
# ...                       ...       ...           ...             ...
# 1814807     Bacillus phage H1     10765           100               1
# 1814808  midivariant sequence     31896           224               1
# 1814809     Corynephage omega     10714          1905               1
# 1814810     Influenza A virus     79695           291               1
# 1814811     Influenza A virus    385637           331               1
#
# [1814812 rows x 11 columns]

# %%
ranks = ['superkingdom', 'kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']

# %%
all_data.groupby('superkingdom').count()
# Out:
#               kingdom   phylum    class    order   family   genus  species  \
# superkingdom
# Archaea             0     7980     5843     5872     5328    4982     9669
# Bacteria            0   342220   317533   323491   316300  305523   397543
# Eukaryota     1132826  1153781  1146489  1136876  1111078  913150  1175137
# Viruses        177994   177897   177925   177888   178509  163846   185133
#
#               taxon_id  total_length  num_accessions
# superkingdom
# Archaea           9672          9672            9672
# Bacteria        397573        397573          397573
# Eukaryota      1175177       1175177         1175177
# Viruses         185149        185149          185149

# %% [markdown]
# Explore NaN values in data.

# %%
other_sequences = all_data[all_data.superkingdom.isna()].sort_values(by='num_accessions', ascending=False) # 'other sequences', not actual species
other_sequences
# Out:
#         superkingdom kingdom phylum class order family genus  \
# 37860            NaN     NaN    NaN   NaN   NaN    NaN   NaN
# 1534             NaN     NaN    NaN   NaN   NaN    NaN   NaN
# 26922            NaN     NaN    NaN   NaN   NaN    NaN   NaN
# 3925             NaN     NaN    NaN   NaN   NaN    NaN   NaN
# 52731            NaN     NaN    NaN   NaN   NaN    NaN   NaN
# ...              ...     ...    ...   ...   ...    ...   ...
# 707267           NaN     NaN    NaN   NaN   NaN    NaN   NaN
# 707268           NaN     NaN    NaN   NaN   NaN    NaN   NaN
# 707269           NaN     NaN    NaN   NaN   NaN    NaN   NaN
# 707270           NaN     NaN    NaN   NaN   NaN    NaN   NaN
# 1814808          NaN     NaN    NaN   NaN   NaN    NaN   NaN
#
#                           species  taxon_id  total_length  num_accessions
# 37860         uncultured organism    155900     314401643          267990
# 1534          synthetic construct     32630     237367640          217078
# 26922       uncultured prokaryote    198431      65845061          170392
# 3925                 unidentified     32644      50756966          114244
# 52731    uncultured microorganism    358574      37313762           86083
# ...                           ...       ...           ...             ...
# 707267                        NaN   2928127           328               1
# 707268                        NaN   2928128           328               1
# 707269                        NaN   2928129           328               1
# 707270                        NaN   2928130           328               1
# 1814808      midivariant sequence     31896           224               1
#
# [47241 rows x 11 columns]

# %% [markdown]
# Sum up the length and accessions for the 'other_sequences', drop the rows, and add a new row aggregating them.

# %%
length_sum = other_sequences.total_length.sum()
accession_sum = other_sequences.num_accessions.sum()

# %%
all_data.dropna(subset='superkingdom', inplace=True)
data = ["other_sequences"] * len(ranks) + [-1, length_sum, accession_sum]
df2 = pd.DataFrame([data], columns = all_data.columns)
all_data = pd.concat([df2, all_data], ignore_index=True)
all_data
# Out:
#             superkingdom          kingdom           phylum            class  \
# 0        other_sequences  other_sequences  other_sequences  other_sequences
# 1              Eukaryota          Metazoa         Chordata       Ascidiacea
# 2              Eukaryota          Metazoa       Arthropoda          Insecta
# 3              Eukaryota          Metazoa       Arthropoda          Insecta
# 4              Eukaryota          Metazoa         Chordata         Mammalia
# ...                  ...              ...              ...              ...
# 1767567          Viruses     Shotokuvirae    Cossaviricota  Quintoviricetes
# 1767568          Viruses   Heunggongvirae      Uroviricota   Caudoviricetes
# 1767569          Viruses   Heunggongvirae      Uroviricota   Caudoviricetes
# 1767570          Viruses    Orthornavirae  Negarnaviricota  Insthoviricetes
# 1767571          Viruses    Orthornavirae  Negarnaviricota  Insthoviricetes
#
#                    order            family                genus  \
# 0        other_sequences   other_sequences      other_sequences
# 1        Stolidobranchia         Styelidae               Styela
# 2              Hemiptera       Delphacidae          Nilaparvata
# 3            Hymenoptera        Formicidae           Solenopsis
# 4               Primates           Cebidae              Saimiri
# ...                  ...               ...                  ...
# 1767567     Piccovirales      Parvoviridae      Protoparvovirus
# 1767568     Caudovirales    Herelleviridae           Okubovirus
# 1767569     Caudovirales      Siphoviridae          Lambdavirus
# 1767570  Articulavirales  Orthomyxoviridae  Alphainfluenzavirus
# 1767571  Articulavirales  Orthomyxoviridae  Alphainfluenzavirus
#
#                           species  taxon_id  total_length  num_accessions
# 0                 other_sequences        -1    3980308547         1140428
# 1                    Styela clava      7725      82293180           30498
# 2              Nilaparvata lugens    108931     111856641           39851
# 3              Solenopsis invicta     13686     127796499           34709
# 4             Saimiri boliviensis     39432     154142035           53060
# ...                           ...       ...           ...             ...
# 1767567  Rodent protoparvovirus 1     10800           127               1
# 1767568         Bacillus phage H1     10765           100               1
# 1767569         Corynephage omega     10714          1905               1
# 1767570         Influenza A virus     79695           291               1
# 1767571         Influenza A virus    385637           331               1
#
# [1767572 rows x 11 columns]

# %% [markdown]
# Bacteria and Archaea are missing kingdoms. Fill in the kingdom level with the superkingdom.

# %%
all_data.loc[all_data.superkingdom == 'Archaea', 'kingdom']= all_data[all_data.superkingdom == 'Archaea'].kingdom.fillna(all_data.superkingdom)
all_data.loc[all_data.superkingdom == 'Bacteria', 'kingdom'] = all_data[all_data.superkingdom == 'Bacteria'].kingdom.fillna(all_data.superkingdom)
all_data[(all_data.superkingdom == 'Archaea') | (all_data.superkingdom == 'Bacteria')]
# Out:
#         superkingdom   kingdom          phylum                class  \
# 1434        Bacteria  Bacteria  Actinobacteria        Actinomycetia
# 1450        Bacteria  Bacteria      Firmicutes              Bacilli
# 1452        Bacteria  Bacteria  Actinobacteria        Actinomycetia
# 1453        Bacteria  Bacteria  Actinobacteria        Actinomycetia
# 1454        Bacteria  Bacteria      Firmicutes              Bacilli
# ...              ...       ...             ...                  ...
# 1767536     Bacteria  Bacteria  Proteobacteria  Alphaproteobacteria
# 1767545     Bacteria  Bacteria  Proteobacteria  Gammaproteobacteria
# 1767546     Bacteria  Bacteria  Proteobacteria  Alphaproteobacteria
# 1767559     Bacteria  Bacteria   Cyanobacteria                  NaN
# 1767561     Bacteria  Bacteria   Cyanobacteria                  NaN
#
#                      order              family          genus  \
# 1434     Corynebacteriales    Mycobacteriaceae  Mycobacterium
# 1450            Bacillales         Bacillaceae       Bacillus
# 1452      Streptomycetales   Streptomycetaceae   Streptomyces
# 1453      Streptomycetales   Streptomycetaceae   Streptomyces
# 1454       Lactobacillales    Streptococcaceae  Streptococcus
# ...                    ...                 ...            ...
# 1767536      Rickettsiales     Anaplasmataceae      Wolbachia
# 1767545   Enterobacterales  Enterobacteriaceae     Salmonella
# 1767546   Sphingomonadales   Sphingomonadaceae   Sphingomonas
# 1767559    Synechococcales    Synechococcaceae  Synechococcus
# 1767561   Pseudanabaenales    Leptolyngbyaceae   Leptolyngbya
#
#                            species  taxon_id  total_length  num_accessions
# 1434          Mycobacterium leprae      1769       9807686             403
# 1450        Bacillus thuringiensis      1428     347410425            7821
# 1452         Streptomyces lividans      1916      25846403             225
# 1453       Streptomyces coelicolor      1902      18096169             228
# 1454        Streptococcus pyogenes      1314     443844907            4159
# ...                            ...       ...           ...             ...
# 1767536                        NaN       953           207               1
# 1767545                        NaN       590           205               1
# 1767546       Sphingomonas sp. WI4    106806           271               1
# 1767559                        NaN      1129          1886               6
# 1767561  Leptolyngbya sp. PCC 6402    272136          4247               1
#
# [407245 rows x 11 columns]

# %% [markdown]
# Look at groupings by superkingdom again.

# %%
all_data.groupby('superkingdom').count()
# Out:
#                  kingdom   phylum    class    order   family   genus  species  \
# superkingdom
# Archaea             9672     7980     5843     5872     5328    4982     9669
# Bacteria          397573   342220   317533   323491   316300  305523   397543
# Eukaryota        1132826  1153781  1146489  1136876  1111078  913150  1175137
# Viruses           177994   177897   177925   177888   178509  163846   185133
# other_sequences        1        1        1        1        1       1        1
#
#                  taxon_id  total_length  num_accessions
# superkingdom
# Archaea              9672          9672            9672
# Bacteria           397573        397573          397573
# Eukaryota         1175177       1175177         1175177
# Viruses            185149        185149          185149
# other_sequences         1             1               1

# %%
#what percentage of rows are NA?
(all_data.shape[0] - all_data.dropna().shape[0])/all_data.shape[0]
# Out:
# 0.2592986311165825

# %%
all_data[all_data["kingdom"] =="Eukaryota"]
# Out:
# Empty DataFrame
# Columns: [superkingdom, kingdom, phylum, class, order, family, genus, species, taxon_id, total_length, num_accessions]
# Index: []

# %%
# backfill missing ranks to get rid of NAs
# all data has superkingdom at least
def backfill_data(ranks, df): 
  for rank in ranks:
    df[rank] = df[rank].fillna(f'unknown_{rank}')

  return df

all_data = backfill_data(ranks, all_data)

# %%
all_data[0:20]
# Out:
#        superkingdom          kingdom           phylum            class  \
# 0   other_sequences  other_sequences  other_sequences  other_sequences
# 1         Eukaryota          Metazoa         Chordata       Ascidiacea
# 2         Eukaryota          Metazoa       Arthropoda          Insecta
# 3         Eukaryota          Metazoa       Arthropoda          Insecta
# 4         Eukaryota          Metazoa         Chordata         Mammalia
# 5         Eukaryota          Metazoa         Chordata    unknown_class
# 6         Eukaryota          Metazoa         Chordata             Aves
# 7         Eukaryota          Metazoa       Arthropoda          Insecta
# 8         Eukaryota          Metazoa         Chordata      Actinopteri
# 9         Eukaryota          Metazoa       Arthropoda          Insecta
# 10        Eukaryota          Metazoa         Chordata         Mammalia
# 11        Eukaryota    Viridiplantae     Streptophyta    Magnoliopsida
# 12        Eukaryota          Metazoa         Chordata      Actinopteri
# 13        Eukaryota          Metazoa         Chordata        Cladistia
# 14        Eukaryota          Metazoa         Chordata      Actinopteri
# 15        Eukaryota          Metazoa         Chordata             Aves
# 16        Eukaryota    Viridiplantae     Streptophyta    Magnoliopsida
# 17        Eukaryota    Viridiplantae     Streptophyta    Magnoliopsida
# 18        Eukaryota  unknown_kingdom      Apicomplexa     Aconoidasida
# 19        Eukaryota          Metazoa         Chordata         Mammalia
#
#               order             family            genus  \
# 0   other_sequences    other_sequences  other_sequences
# 1   Stolidobranchia          Styelidae           Styela
# 2         Hemiptera        Delphacidae      Nilaparvata
# 3       Hymenoptera         Formicidae       Solenopsis
# 4          Primates            Cebidae          Saimiri
# 5        Testudines        Geoemydidae         Mauremys
# 6     Passeriformes           Corvidae           Corvus
# 7           Diptera          Culicidae            Culex
# 8      Cichliformes          Cichlidae      Oreochromis
# 9       Lepidoptera        Nymphalidae          Pararge
# 10      Monotremata  Ornithorhynchidae  Ornithorhynchus
# 11           Poales            Poaceae          Panicum
# 12     Cichliformes          Cichlidae      Simochromis
# 13  Polypteriformes       Polypteridae       Polypterus
# 14      Perciformes           Percidae            Perca
# 15    Passeriformes         Passeridae           Passer
# 16         Malvales          Malvaceae         Hibiscus
# 17         Arecales          Arecaceae          Phoenix
# 18     Haemosporida       Plasmodiidae       Plasmodium
# 19         Rodentia            Muridae           Rattus
#
#                      species  taxon_id  total_length  num_accessions
# 0            other_sequences        -1    3980308547         1140428
# 1               Styela clava      7725      82293180           30498
# 2         Nilaparvata lugens    108931     111856641           39851
# 3         Solenopsis invicta     13686     127796499           34709
# 4        Saimiri boliviensis     39432     154142035           53060
# 5          Mauremys reevesii    260615     263305466           86524
# 6              Corvus cornix    932674     187689789           42758
# 7              Culex pipiens     42434      76102917           28778
# 8         Oreochromis aureus     47969     182873946           57938
# 9            Pararge aegeria    116150     580760471           22221
# 10  Ornithorhynchus anatinus      9258     159116152           53302
# 11          Panicum virgatum     38727     246652575          119020
# 12     Simochromis diagramma     43689     236429994           61544
# 13      Polypterus senegalus     55291     151672045           48638
# 14         Perca fluviatilis      8168     183424350           56117
# 15           Passer montanus      9160     165270171           43506
# 16         Hibiscus syriacus    106335     129522710           91962
# 17       Phoenix dactylifera     42345     150681391           62082
# 18       Plasmodium knowlesi      5851      36103153            5364
# 19         Rattus norvegicus     10116     695771729          213574

# %% [markdown]
# Group data by ranks up to desired level of granularity.

# %%
groupby_col = 'order'
df_grouped = all_data.groupby(ranks[0: ranks.index(groupby_col)+1], as_index=False).agg(
  {
    'family': 'unique',
    'genus': 'unique',
    'species': 'unique',
    'taxon_id': 'unique',
    'total_length': 'sum', 
    'num_accessions': 'sum'
  })

df_grouped.to_csv('all_data_order_grouped.csv')

# %%
df_grouped
# Out:
#          superkingdom          kingdom                        phylum  \
# 0             Archaea          Archaea    Candidatus Aenigmarchaeota
# 1             Archaea          Archaea     Candidatus Bathyarchaeota
# 2             Archaea          Archaea     Candidatus Diapherotrites
# 3             Archaea          Archaea       Candidatus Geoarchaeota
# 4             Archaea          Archaea  Candidatus Heimdallarchaeota
# ...               ...              ...                           ...
# 2111          Viruses      Zilligvirae                 Taleaviricota
# 2112          Viruses  unknown_kingdom                unknown_phylum
# 2113          Viruses  unknown_kingdom                unknown_phylum
# 2114          Viruses  unknown_kingdom                unknown_phylum
# 2115  other_sequences  other_sequences               other_sequences
#
#                 class            order  \
# 0       unknown_class    unknown_order
# 1       unknown_class    unknown_order
# 2       unknown_class    unknown_order
# 3       unknown_class    unknown_order
# 4       unknown_class    unknown_order
# ...               ...              ...
# 2111    Tokiviricetes     Primavirales
# 2112   Naldaviricetes      Lefavirales
# 2113   Naldaviricetes    unknown_order
# 2114    unknown_class    unknown_order
# 2115  other_sequences  other_sequences
#
#                                                  family  \
# 0                                      [unknown_family]
# 1                                      [unknown_family]
# 2                                      [unknown_family]
# 3                                      [unknown_family]
# 4                                      [unknown_family]
# ...                                                 ...
# 2111                                 [Tristromaviridae]
# 2112       [Baculoviridae, Hytrosaviridae, Nudiviridae]
# 2113                                      [Nimaviridae]
# 2114  [Kolmioviridae, Pospiviroidae, unknown_family,...
# 2115                                  [other_sequences]
#
#                                                   genus  \
# 0            [Candidatus Aenigmarchaeum, unknown_genus]
# 1                                       [unknown_genus]
# 2                 [unknown_genus, Candidatus Forterrea]
# 3                                       [unknown_genus]
# 4                                       [unknown_genus]
# ...                                                 ...
# 2111          [Betatristromavirus, Alphatristromavirus]
# 2112  [Alphabaculovirus, Betabaculovirus, unknown_ge...
# 2113                                      [Whispovirus]
# 2114  [Deltavirus, Coleviroid, unknown_genus, Hostuv...
# 2115                                  [other_sequences]
#
#                                                 species  \
# 0     [uncultured Candidatus Aenigmarchaeum sp., unc...
# 1     [uncultured miscellaneous Crenarchaeota group,...
# 2     [uncultured Diapherotrites archaeon, Candidatu...
# 3                    [uncultured Geoarchaeota archaeon]
# 4     [Candidatus Heimdallarchaeota archaeon, Candid...
# ...                                                 ...
# 2111  [Betatristromavirus TTV1, Alphatristromavirus ...
# 2112  [Bombyx mori nucleopolyhedrovirus, Autographa ...
# 2113  [White spot syndrome virus, Metopaulias depres...
# 2114  [Hepatitis delta virus, Coleus blumei viroid 1...
# 2115                                  [other_sequences]
#
#                                                taxon_id  total_length  \
# 0                           [1896161, 1462426, 2093792]       3748249
# 1     [1368239, 1739975, 2026714, 907719, 907717, 90...      34576843
# 2                           [1462420, 2107591, 2026736]       1913635
# 3                                             [1448936]          2711
# 4                           [2026747, 2876573, 2876572]      16162785
# ...                                                 ...           ...
# 2111                          [10479, 1805492, 2730621]         54302
# 2112  [271108, 46015, 28289, 74320, 10469, 10456, 46...      47177140
# 2113           [342409, 92652, 1675544, 2488332, 46615]       9748026
# 2114  [12475, 192025, 12436, 195062, 12893, 12412, 1...     379543353
# 2115                                               [-1]    3980308547
#
#       num_accessions
# 0                 20
# 1                217
# 2                  4
# 3                  2
# 4                 47
# ...              ...
# 2111               6
# 2112            2903
# 2113             539
# 2114           76215
# 2115         1140428
#
# [2116 rows x 11 columns]

# %%
df_grouped.shape[0]
# Out:
# 2116

# %% [markdown]
# If we didn't run the step for filling NA values, how many rows are we losing by grouping data, which implicitly drops NAs?

# %%
all_data.shape[0] - all_data.dropna().shape[0]

# %%
for col in all_data.columns:
  print(f'NA values in column {col}: ')
  print(all_data[col].isna().sum())
# Out:
# NA values in column superkingdom:
# 0
# NA values in column kingdom:
# 0
# NA values in column phylum:
# 0
# NA values in column class:
# 0
# NA values in column order:
# 0
# NA values in column family:
# 0
# NA values in column genus:
# 0
# NA values in column species:
# 0
# NA values in column taxon_id:
# 0
# NA values in column total_length:
# 0
# NA values in column num_accessions:
# 0
